# %% [markdown]
# <a href="https://colab.research.google.com/github/NoahCorlew/CAP4630-Homework/blob/master/HW_3/CAP4630_Homework_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem 1

# %%
import numpy
import time
import math
import random
import matplotlib.pyplot as plt
from numpy.random import seed
from numpy.random import rand
# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.patches as mpatches

def get_random_data(w, b, mu, sigma, m):
  data = numpy.zeros((m,2))
  labels = numpy.zeros((m,1))

  # Looping m times to calculate x1 and x2
  for i in range(m):
    x1 = rand(1)

    randn = rand(1)
    if (randn >= .5):
      c = 0
    if (randn < .5):
      c = 1

    n = numpy.random.normal(mu, sigma)
    x2 = w * x1 + b + ((-1)**c) * n

    data[i][0] = x1
    data[i][1] = x2
    labels[i] = c

  display_random_data(data, labels, w, b)

  return data, labels


def display_random_data (data, labels, w, b):
  data_c0 = [] # Red dots
  data_c1 = [] # Blue dots

  i = 0
  while i != len(labels):
    if labels[i] == 0:
      data_c0.append(data[i])
    if labels[i] == 1:
      data_c1.append(data[i])
    i += 1

  # Separates out the x and y values from the tuples to be plotted on the scatter plot
  data_c0_x = [val[0] for val in data_c0]
  data_c0_y = [val[1] for val in data_c0]

  data_c1_x = [val[0] for val in data_c1]
  data_c1_y = [val[1] for val in data_c1]

  plt.scatter(data_c0_x, data_c0_y, c = "blue")
  plt.scatter(data_c1_x, data_c1_y, c = "red")

  x = numpy.linspace(0,1,100)
  y = w * x + b
  plt.plot(x , y)
  
  plt.show()


wIn = numpy.random.default_rng().uniform(0,1)
bIn = 3
muIn = 4
sigmaIn = 1
mIn = 10000

data, labels = get_random_data(wIn, bIn, muIn, sigmaIn, mIn)

# %% [markdown]
# Split the data/labels into a training set (80%) and a test set (20%).

# %%
split = int (len(data) * .2)
test_data, training_data = data[:split], data[split:]
test_labels, training_labels = labels[:split], labels[split:]

# %% [markdown]
# # Problem 2 Helper Functions

# %%
# This function is used later in problem 3 as well
def plot_random_data_with_lines(labels, data, weights, bias, wIn, bIn):

  x1_blue = []
  x2_blue = []
  x1_red = []
  x2_red = []

  for i in range(len(data)):
    c = labels[i]

    if (c == 0):
      x1_blue.append(data[i,0])
      x2_blue.append(data[i,1])
    else:
      x1_red.append(data[i,0])
      x2_red.append(data[i,1])
  
  plt.plot(x1_blue, x2_blue, "b.")
  plt.plot(x1_red, x2_red, "r.")

  # predicted Line
  px1 = numpy.linspace(0, 1, 100)
  px2 = ((-1 * weights[0] * px1) - bias )/ weights[1] 
  plt.plot(px1, px2, "-k")

  # actual Line
  ax1 = numpy.linspace(0, 1, 100)
  ax2 = wIn * ax1 + bIn
  plt.plot(ax1, ax2, "-g")

  actual_line = mpatches.Patch(color = "green", label = "Actual")
  predicted_line = mpatches.Patch(color = "black", label = "Predicted")
  plt.legend(handles = [actual_line, predicted_line])

  return max(x2_blue), min(x2_red)

# %% [markdown]
# # Problem 2 Training

# %%
# Build
model = tf.keras.models.Sequential()

layers = tf.keras.layers.Dense(1, activation = "sigmoid", input_shape = (2,))
model.add(layers)


# Compile
model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.005), loss = "binary_crossentropy", metrics = ["accuracy"])

# Train and Display
print(weights)

model.fit(training_data, training_labels, epochs = 80, batch_size = 500)
weights, bias = layers.get_weights()

print(model.evaluate(test_data, test_labels))
# Out:
# [[ 5.278804]
#  [-2.447896]]
# Epoch 1/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2886 - accuracy: 0.8501
# Epoch 2/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2568 - accuracy: 0.8801
# Epoch 3/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2332 - accuracy: 0.8981
# Epoch 4/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2126 - accuracy: 0.9122
# Epoch 5/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1942 - accuracy: 0.9237
# Epoch 6/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1776 - accuracy: 0.9349
# Epoch 7/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1626 - accuracy: 0.9455
# Epoch 8/80
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1488 - accuracy: 0.9542
# Epoch 9/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1360 - accuracy: 0.9635
# Epoch 10/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1242 - accuracy: 0.9701
# Epoch 11/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1134 - accuracy: 0.9768
# Epoch 12/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1034 - accuracy: 0.9816
# Epoch 13/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0943 - accuracy: 0.9851
# Epoch 14/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0860 - accuracy: 0.9879
# Epoch 15/80
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9910
# Epoch 16/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0715 - accuracy: 0.9925
# Epoch 17/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0652 - accuracy: 0.9942
# Epoch 18/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0595 - accuracy: 0.9958
# Epoch 19/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0543 - accuracy: 0.9969
# Epoch 20/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0496 - accuracy: 0.9973
# Epoch 21/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9976
# Epoch 22/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0414 - accuracy: 0.9980
# Epoch 23/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 0.9980
# Epoch 24/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0346 - accuracy: 0.9980
# Epoch 25/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0317 - accuracy: 0.9983
# Epoch 26/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 0.9985
# Epoch 27/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0267 - accuracy: 0.9987
# Epoch 28/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0245 - accuracy: 0.9987
# Epoch 29/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0225 - accuracy: 0.9987
# Epoch 30/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0207 - accuracy: 0.9989
# Epoch 31/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.9990
# Epoch 32/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0175 - accuracy: 0.9991
# Epoch 33/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9991
# Epoch 34/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 0.9992
# Epoch 35/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0138 - accuracy: 0.9994
# Epoch 36/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.9994
# Epoch 37/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 0.9996
# Epoch 38/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 0.9998
# Epoch 39/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.9998
# Epoch 40/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 0.9998
# Epoch 41/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 0.9998
# Epoch 42/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9998
# Epoch 43/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.9998
# Epoch 44/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.9998
# Epoch 45/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.9998
# Epoch 46/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 0.9998
# Epoch 47/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 0.9998
# Epoch 48/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 0.9998
# Epoch 49/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 0.9998
# Epoch 50/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 0.9998
# Epoch 51/80
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 0.9998
# Epoch 52/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 0.9998
# Epoch 53/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 0.9998
# Epoch 54/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 0.9998
# Epoch 55/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0036 - accuracy: 0.9998
# Epoch 56/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 0.9998
# Epoch 57/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0032 - accuracy: 0.9998
# Epoch 58/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 0.9998
# Epoch 59/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 0.9998
# Epoch 60/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0027 - accuracy: 0.9998
# Epoch 61/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 0.9998
# Epoch 62/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0025 - accuracy: 0.9998
# Epoch 63/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0023 - accuracy: 0.9998
# Epoch 64/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 0.9998
# Epoch 65/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0021 - accuracy: 0.9998
# Epoch 66/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 67/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 68/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 0.9998
# Epoch 69/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 0.9998
# Epoch 70/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 71/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 72/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 73/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 74/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 0.9999
# Epoch 75/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0014 - accuracy: 0.9999
# Epoch 76/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0014 - accuracy: 0.9999
# Epoch 77/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9999
# Epoch 78/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9999
# Epoch 79/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9999
# Epoch 80/80
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 0.9999
# 63/63 [==============================] - 0s 1ms/step - loss: 9.4883e-04 - accuracy: 1.0000
# [0.0009488338837400079, 1.0]

# %% [markdown]
# # Problem 2 Plots

# %%
ymax, ymin = plot_random_data_with_lines(labels, data, weights, bias, wIn, bIn)

px1, px2 = numpy.meshgrid(numpy.linspace(0, 1), numpy.linspace(ymin, ymax))

plt.title("Problem 2 Random Data and Prediction Plot")
plt.show()

# %% [markdown]
# Heatmap to visualize the function f : R^2 -> R

# %%
z = weights[0] * px1 + weights[1] * px2 + bias
p = 1.0 / (1.0 + numpy.exp(numpy.negative(z)))

plt.contourf(px1, px2, p, 100, cmap = "bwr", alpha = 0.5, zorder = -1)
plt.ylim(ymin, ymax)
plt.colorbar()
plt.title("Problem 2 Heatmap")
plt.show()

# %% [markdown]
# *How well does the trained model separate the red and blue dots?*
#
# The trained model separates the dots reasonably well

# %% [markdown]
# # Problem 3 Training

# %%
learning_rate = 0.01
epochs = 80

weights = numpy.random.randn(2)
bias = numpy.zeros(1)

for epoch in range(epochs):

  shuffled_indices = numpy.random.permutation(len(data))

  for i in range(len(data)):
    a = sigmoid_function(data[i].dot(weights) + bias)
    loss = -1 * labels[i] * math.log(a, 10) - (1-labels[i])
    
    bias_gradient = a - labels[i]
    weight_gradient = bias_gradient * data[i]
    
    weights = weights - learning_rate * weight_gradient
    bias = bias - learning_rate * bias_gradient

# %% [markdown]
# # Problem 3 Plots

# %% [markdown]
# Create a plot showing the random data, the true line used to generate the data, and the separating line of the trained model.

# %%
ymax, ymin = plot_random_data_with_lines(labels, data, weights, bias, wIn, bIn)
plt.title("Problem 3 Random Data and Prediction Plot")
plt.show()

# %% [markdown]
# Use a heatmap to visualize the function defined by your trained model

# %%
x1, x2 = numpy.meshgrid(numpy.linspace(0, 1), numpy.linspace(ymin, ymax))

z = weights[0] * x1 + weights[1] * x2 + bias
p = 1.0 / (1.0 + numpy.exp(numpy.negative(z)))

plt.contourf(x1, x2, p, 100, cmap = "bwr", alpha = 0.5, zorder = -1)
plt.colorbar()
plt.title("Problem 3 Heatmap")
plt.show()

# %% [markdown]
# Compute the binary cross entropy loss and accuracy on the test set.

# %%
c = 0
for i in range(len(test_data)):

  a = sigmoid_function(test_data[i].dot(weights) + bias)
  loss = loss - (test_labels[i] * math.log(a, 2)) - ((1-test_labels[i]) * math.log(a, 2))
  
  if (a < .5 and test_labels[i] == 0) or (a >= .5 and test_labels[i] == 1):
      c = c + 1

bcel = loss[0] / len(test_data)
ac = c / len(test_data)

print("Test set binary cross entropy loss: " + str(bcel))
print("Test set accuracy: " + str(ac))
# Out:
# Test set binary cross entropy loss: 8.287899721396109
# Test set accuracy: 1.0
